# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
x = np.linspace(-10, 10, 200)

# %%
y = np.sin(x)

# %%
plt.figure()
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
